# %%
import pandas as pd

# %%
df= pd.read_csv('D:/practice/Dataset/Housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.tail(10)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 535  2100000  3360         2          1        1      yes        no       no
# 536  1960000  3420         5          1        2       no        no       no
# 537  1890000  1700         3          1        2      yes        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 539  1855000  2990         2          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df1 =df.iloc[:, [1]]

# %%
df1
# Out:
#      area
# 0    7420
# 1    8960
# 2    9960
# 3    7500
# 4    7420
# ..    ...
# 540  3000
# 541  2400
# 542  3620
# 543  2910
# 544  3850
#
# [545 rows x 1 columns]

# %%
X= df1

# %%
y=df.iloc[:, [0]]

# %%
y
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
df1
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
df1.iloc[:,4]
# Out:
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4      yes
#       ...
# 540    yes
# 541     no
# 542    yes
# 543     no
# 544    yes
# Name: mainroad, Length: 545, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencoder=LabelEncoder()

# %%
df1['mainroad']
# Out:
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4      yes
#       ...
# 540    yes
# 541     no
# 542    yes
# 543     no
# 544    yes
# Name: mainroad, Length: 545, dtype: object

# %%
df1['guestroom']= lencoder.fit_transform(df1['guestroom'])
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6764/3638679278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['guestroom']= lencoder.fit_transform(df1['guestroom'])

# %%
df1['basement']=lencoder.fit_transform(df1['basement'])
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6764/506348913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['basement']=lencoder.fit_transform(df1['basement'])

# %%
# df.loc[:,('one','second')]
# df1['hotwaterheating']=lencoder.fit_transform(df1['hotwaterheating'])
df1['furnishingstatus']=lencoder.fit_transform(df1['furnishingstatus'])
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_6764/752151567.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['furnishingstatus']=lencoder.fit_transform(df1['furnishingstatus'])

# %%
df1
# Out:
#      area  bedrooms  bathrooms  stories mainroad  guestroom  basement  \
# 0    7420         4          2        3      yes          0         0
# 1    8960         4          4        4      yes          0         0
# 2    9960         3          2        2      yes          0         1
# 3    7500         4          2        2      yes          0         1
# 4    7420         4          1        2      yes          1         1
# ..    ...       ...        ...      ...      ...        ...       ...
# 540  3000         2          1        1      yes          0         1
# 541  2400         3          1        1       no          0         0
# 542  3620         2          1        1      yes          0         0
# 543  2910         3          1        1       no          0         0
# 544  3850         3          1        2      yes          0         0
#
#     hotwaterheating airconditioning  parking prefarea  furnishingstatus
# ...

# %%
#import Model
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[ 2.43906887e+02,  1.19474386e+05,  9.88888287e+05,
#          4.50391518e+05,  4.23100741e+05,  2.98030507e+05,
#          3.57926360e+05,  8.72936027e+05,  8.53633595e+05,
#          2.79785637e+05,  6.47055599e+05, -2.13187781e+05]])

# %%
model.intercept_
# Out:
# array([2387308.48239643])

# %%
model.predict([[2000]])
# Out:
# array([[3311258.270942]])

# %%
model.score(X,y)
# Out:
# 0.2872931546811468
